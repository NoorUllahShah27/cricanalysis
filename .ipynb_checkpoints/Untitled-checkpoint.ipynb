# %%
import Converter

# %%
Converter.euro(200)
# Out:
# Your euro to PKR is 76000

# %%
Converter.riyal(300)
# Out:
# Your riyal to PKR is 24300

# %%
Converter.dirham(400), Converter.usd(100)
# Out:
# Your dirham to PKR is 31600
# Your USD to PKR is 27600
# (None, None)
